# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Administrator.DAI-PC2\Desktop\archive\Employee_monthly_salary.csv')
df
# Out:
#       EmpID              Name Gender Date_of_Birth  Age   Join_Date  \
# 0     19575      Keven Norman      M        3/9/94   25     2/12/19
# 1     19944    Kristin Werner      F    23/06/1994   26  13/01/2020
# 2     20055      Avery Barber      M    27/02/1996   24  14/11/2019
# 3     20058      Boris Gibson      M    29/09/1993   26  13/01/2020
# 4     20332         Leif Mack      M        1/5/91   29      4/6/18
# ...     ...               ...    ...           ...  ...         ...
# 1797  18835  Darius Wilkerson      M    14/01/1991   29  21/08/2017
# 1798  19066     Erick Ballard      M    29/08/1992   27  25/09/2017
# 1799  21644   Lawerence Downs      M        5/7/91   29      1/4/19
# 1800  19673     Abdul Watkins      M    19/08/1972   47  26/12/2017
# 1801  19790   Chase Fernandez      M    20/03/1993   27  22/01/2018
#
#       Tenure_in_org_in_months   GROSS  Net_Pay  Deduction  \
# 0                           7   74922    71494       3428
# ...

# %%
d = df['Gender'].value_counts()
d
# Out:
# Gender
# M    1303
# F     499
# Name: count, dtype: int64

# %%
from scipy import stats
# Separate the monthly income data into two groups: males and females
male_income = df[df['Gender'] == 'M']['Net_Pay']
female_income = df[df['Gender'] == 'F']['Net_Pay']

# Perform an independent t-test
t_stat, p_val = stats.ttest_ind(male_income, female_income)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")

# Interpret the p-value
alpha = 0.05  # significance level
if p_val < alpha:
    print("We reject the null hypothesis. There is a significant difference between the monthly incomes.")
else:
    print("We fail to reject the null hypothesis. There is no significant difference between the monthly incomes.")
# Out:
# T-statistic: 7.56557596200575
# P-value: 6.123835411537334e-14
# We reject the null hypothesis. There is a significant difference between the monthly incomes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1802 entries, 0 to 1801
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmpID                    1802 non-null   int64
#  1   Name                     1802 non-null   object
#  2   Gender                   1802 non-null   object
#  3   Date_of_Birth            1802 non-null   object
#  4   Age                      1802 non-null   int64
#  5   Join_Date                1802 non-null   object
#  6   Tenure_in_org_in_months  1802 non-null   int64
#  7   GROSS                    1802 non-null   int64
#  8   Net_Pay                  1802 non-null   int64
#  9   Deduction                1802 non-null   int64
#  10  Deduction_percentage     1802 non-null   float64
#  11  Designation              1802 non-null   object
#  12  Department               1802 non-null   object
# dtypes: float64(1), int64(6), object(6)
# memory usage: 183.1+ KB

# %% [markdown]
# Q2. Draw right Visualization graphs to answer following questions
# (Mark distribution: 5 marks for each correct gra
# IZ
# a. Draw Histogram of any 5 relevant columns
# b. Draw Pie chart of any 5 relevant columns
# c. Draw Boxplot of any 5 relevant columns

# %%
# Selecting 5 relevant columns for the histogram
columns_to_plot = ['Age', 'Tenure_in_org_in_months', 'GROSS', 'Net_Pay', 'Deduction']

# Plotting histograms
for column in columns_to_plot:
    plt.figure()
    plt.hist(df[column], bins=10, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
plt.figure(figsize=(10, 8))
df.boxplot(column=['Age', 'Tenure_in_org_in_months', 'GROSS', 'Net_Pay', 'Deduction'])
plt.title('Boxplot of Selected Columns')
plt.show()

# %%
# Replace 'column_name' with the actual names of your categorical columns
# This is an example using 'Gender' column
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Gender Distribution')
plt.show()
