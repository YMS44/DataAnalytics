# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dm_office_sales.csv")
print(df.head())
print(df.info())

sns.scatterplot(x='salary',y='sales',data=df)
plt.show() #Note that seaborn is linked to matplotlib underneath
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   division            1000 non-null   object
#  1   level of education  1000 non-null   object
#  2   training level      1000 non-null   int64
#  3   work experience     1000 non-null   int64
# ...

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='salary',y='sales',data=df)
plt.show()

# %%
# hue: Color points based off a categorical feature in the DataFrame
plt.figure(figsize=(12, 8))
sns.scatterplot(x='salary',y='sales',data=df, hue='division')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='salary',y='sales',data=df, hue='work experience')
plt.show()

# %%
# Choosing a palette from Matplotlib's cmap:
# https://matplotlib/org/tutorials/colors/colormaps.html

plt.figure(figsize=(12, 8))
sns.scatterplot(x='salary',y='sales',data=df, hue='work experience', palette='viridis')
plt.show()

# %%
# Use *s=* if you want to change the marker size to be some uniform integer value
plt.figure(figsize=(12, 8))
sns.scatterplot(x='salary',y='sales',data=df, s=200)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='salary',y='sales',data=df, s=200, linewidth=0, alpha=0.2)
plt.show()

# %%
# style
plt.figure(figsize=(12, 8))
sns.scatterplot(x='salary',y='sales',data=df, s=200, style='level of education')
plt.show()

# %%
plt.figure(figsize=(12, 8))
# Sometimes its nice to do BOTH hue and style of the same column
sns.scatterplot(x='salary',y='sales',data=df, style="level of education", hue="level of education", s=100)
plt.show()

# %%
sns.rugplot(x='salary', data=df)
sns.rugplot(x='salary', data=df, height=0.5)
plt.show()

# %%
# displot: Distribution of a single feature
sns.displot(data=df, x='salary', kde=False)
plt.show()

# %%
sns.displot(data=df, x='salary', kde=True)
plt.show()

# %%
#bins
sns.histplot(data=df,x='salary',bins=100)
plt.show()

# %%
sns.set(style='darkgrid')
sns.histplot(data=df,x='salary',bins=100)
plt.show()

# %%
sns.set(style='white')
sns.histplot(data=df,x='salary',bins=100)
plt.show()

# %%
# KDE
import numpy as np
np.random.seed(42)

sample_ages = np.random.randint(0, 100, 200)
print(sample_ages)

sample_ages = pd.DataFrame(sample_ages, columns=['age'])
print(sample_ages.head())
# Out:
# [51 92 14 71 60 20 82 86 74 74 87 99 23  2 21 52  1 87 29 37  1 63 59 20
#  32 75 57 21 88 48 90 58 41 91 59 79 14 61 61 46 61 50 54 63  2 50  6 20
#  72 38 17  3 88 59 13  8 89 52  1 83 91 59 70 43  7 46 34 77 80 35 49  3
#   1  5 53  3 53 92 62 17 89 43 33 73 61 99 13 94 47 14 71 77 86 61 39 84
#  79 81 52 23 25 88 59 40 28 14 44 64 88 70  8 87  0  7 87 62 10 80  7 34
#  34 32  4 40 27  6 72 71 11 33 32 47 22 61 87 36 98 43 85 90 34 64 98 46
#  77  2  0  4 89 13 26  8 78 14 89 41 76 50 62 95 51 95  3 93 22 14 42 28
#  35 12 31 70 58 85 27 65 41 44 61 56  5 27 27 43 83 29 61 74 91 88 61 96
#   0 26 61 76  2 69 71 26]
#    age
# 0   51
# 1   92
# 2   14
# 3   71
# 4   60

# %%
sns.rugplot(data=sample_ages, x='age')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.displot(data=sample_ages, x="age", bins=10, rug=True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.displot(data=sample_ages, x="age", bins=10, rug=True, kde=True)
plt.show()

# %%
sns.kdeplot(data=sample_ages, x="age")
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='level of education',data=df)
plt.show()

# %%
#Breakdown within another category with hue
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='level of education',data=df,hue='training')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 3
#       1 #Breakdown within another category with hue
#       2 plt.figure(figsize=(10,4),dpi=200)
# ----> 3 sns.countplot(x='level of education',data=df,hue='training')
#       4 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
# ...

# %%
#barplot
# So far we have seen the y axis default to a count
plt.figure(figsize=(10,6),dpi=200)
sns.barplot(x='level of education',y='salary',data=df,estimator=np.mean,errorbar='sd')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='level of education',y='salary',data=df,estimator=np.mean,errorbar='sd',hue='division')
plt.show()

# %%
#Box Plot
df = pd.read_csv('StudentsPerformance.csv')
print(df)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='parental level of education',y='math score',data=df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='parental level of education',y='math score',data=df,hue='gender')
plt.show()

# %%
#Changing orientation
sns.boxplot(x='math score', y='parental level of education' ,data=df,orient='h')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y='parental level of education',x='math score',data=df,hue='gender',orient='h')
plt.show()

# %%
#Violin plot
plt.figure(figsize=(12,6))
sns.violinplot(x='parental level of education' ,y='math score',data=df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.violinplot(y='math score', x='parental level of education' ,data=df,hue='gender')
plt.show()

# %%
#split
plt.figure(figsize=(12,6))
sns.violinplot(y='math score', x='parental level of education' ,data=df,hue='gender',split =True)
plt.show()

# %%
#swarmplot
sns.swarmplot(x='math score',data =df)
plt.show()

# %%
sns.swarmplot(x='math score',data =df,size=2)
plt.show()

# %%
sns.swarmplot(x='math score',y='race/ethnicity',data =df,size=3)
plt.show()

# %%
#boxenplot
sns.boxenplot(x='math score',y='race/ethnicity',data =df)
plt.show()

# %%
sns.boxenplot(y='math score',x='race/ethnicity',data =df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxenplot(y='math score',x='race/ethnicity',data =df,hue='gender')
plt.show()

# %%
#2020 Projections
df = pd.read_csv('country_table.csv')
print(df)

# %%
#HeatMap
df=df.set_index('Countries')
print(df)

# %%
#Clearly shows life expentancy in different units
sns.heatmap(df)
plt.show()

# %%
rates = df.drop('Life expectancy',axis=1)
sns.heatmap(rates)
plt.show()

# %%
sns.heatmap(rates,linewidth=0.5)
plt.show()

# %%
sns.heatmap(rates,lw=0.5,annot=True)
plt.show()

# %%
sns.heatmap(rates,linewidth=0.5,annot=True,cmap='viridis')
plt.show()

# %%
#Set colorbar based on value from dataset
sns.heatmap(rates,linewidth=0.5,annot=True,cmap='viridis',center=40)
plt.show()

# %%
#Set colorbar based on value from dataset
sns.heatmap(rates,linewidth=0.5,annot=True,cmap='viridis',center=1)
plt.show()

# %%
print(sns.__version__)

# %%
df=pd.read_csv('MS_Dhoni_ODI_record.csv')
print(df.head())
print(df.tail())

# %%
df['opposition']= df['opposition'].apply(lambda x: x[2:])
df

# %%
import numpy as np
df['date']=pd.to_datetime(df['date'],dayfirst=True)
df['year']=df['date'].dt.year.astype(int) 
df['score']=df['score'].apply(str)
df['not_out']=np.where(df['score'].str.endswith('*'),1,0)
df

# %%
df

# %%
df_new=df.loc[((df['score']!='DNB')& (df['score'] != 'TDNB')),'runs_scored':]
print(df_new)

# %%
df_new['runs_scored']= df_new['runs_scored'].astype(int)
df_new['balls_faced']= df_new['balls_faced'].astype(int)
df_new['strike_rate']= df_new['strike_rate'].astype(float)
df_new['fours']= df_new['fours'].astype(int)
df_new['sixes']= df_new['sixes'].astype(int)
df_new

# %%
first_match_date=df['date'].dt.date.min().strftime('%B %d, %Y')
print('first match:',first_match_date)

# %%
last_match_date=df['date'].dt.date.max().strftime('%B %d, %Y')
print('last match:',last_match_date)

# %%
number_of_matches =df.shape[0]
print('number of  matches:',number_of_matches)

# %%
number_of_inns =df_new.shape[0]
print('number of  inns:',number_of_inns)

# %%
not_outs =df_new['not_out'].sum()
print('not out:',not_outs)

# %%
runs_scored = df_new['runs_scored'].sum()
print("run scored",runs_scored)

# %%
ball_face= df_new['balls_faced'].sum()
print("run scored", ball_face)

# %%
career_sr=(runs_scored/ball_face)*100
print(" career strike rate:{:.2f}".format(career_sr))

# %%
opposition_counts=df['opposition'].value_counts()
print(opposition_counts)
opposition_counts.plot(kind='bar', title='Number of matches against different oppostions', figsize=(8, 5))
plt.show()

# %%
# Run scored against each team
# Group the DataFrame by 'oppostion' column
grouped_by_opposition = df_new.groupby('opposition')

#Sum the 'runs scored' column for each group
sum_of_runs_scored = grouped_by_opposition['runs_scored'].sum()
print(sum_of_runs_scored)

# %%
#sum_of_runs_scored is a Series with a labelled index, which is oppostion
# Convert it into a DataFrame and remove the index
runs_scored_by_opposition = pd.DataFrame(sum_of_runs_scored).reset_index()
runs_scored_by_opposition.plot(x='opposition', kind='bar', title='Runs scored against different oppostions', figsize=(8, 5))
plt.xlabel(None);
plt.show()

# %%
# Does not look good.... Let us Sort it...
sorted = runs_scored_by_opposition.sort_values(by='runs_scored', ascending=False)
sorted.plot(x='opposition', kind='bar', title='Runs scored against different oppostions', figsize=(8, 5))
plt.xlabel(None);
plt.show()

# %%
#Boxplot of runs against various oppositions
sns.boxplot(x='opposition',y='runs_scored',data=df_new)
plt.xticks(rotation=45)
plt.show()

# %%
#Looks crowded - Let us retain only major countries
#List of oppositions to filter
opposition_list = ['England','Australia','West Indies','South Africa','New Zealand','Pakistan','Sri Lanka','Bangladesh']

# %%
#Filter rows where 'opposition' is in the list
df_filtered = df_new[df_new['opposition'].isin(opposition_list)]

# %%
#Sort the filtered DataFrame is descending order of runs_scored
df_filtered = df_filtered.sort_values(by='runs_scored',ascending=False)

# %%
#Redraw boxplot but on filtered opposition  list
sns.boxplot(x='opposition',y='runs_scored',data=df_filtered,hue='opposition')
plt.xticks(rotation=45)
plt.show()

# %%
#Violin Plot
plt.figure(figsize=(12,8))
sns.violinplot(x='opposition',y='runs_scored',data=df_filtered,hue='opposition')
plt.show()

# %%
#displot with and without kde
sns.displot(data=df_filtered,x='runs_scored',kde=False)
plt.show()
#We can see that there is a right/positive skew, so there  is a long tail to the right

# %%
sns.displot(data=df_filtered,x='runs_scored',kde=True)
plt.show()

# %%
#Histogram with bins
sns.set(style='darkgrid')
sns.histplot(data=df_new,x='runs_scored',bins=15)
plt.show()

# %%
# KDE plot
plt.figure(figsize=(12, 8))
sns.kdeplot(data=df_new, x='runs_scored')
plt.show()

# %%
# KDE plot with cumulative probability
plt.figure(figsize=(12, 8))
sns.kdeplot(data=df_new, x='runs_scored', cumulative=True)
plt.show()

# %%
#Jointplot
sns.jointplot(x='balls_faced',y='runs_scored',data=df_new,kind='scatter')
plt.show()

# %%
#heatmap
#calculate the correlation matrix
correlation_matrix = df_new[['balls_faced','runs_scored']].corr()
#create the heatmap
plt.figure(figsize=(8,6))
sns.heatmap(data=correlation_matrix,annot=True,cmap='viridis',square=True,fmt=".2f");

# %%
df['strike_rate'] = (df_new['runs_scored'].sum()/df_new['balls_faced'].sum())*100
sns.displot(data=df_new,x='opposition',y='strike_rate')
plt.xticks(rotation=45)
plt.show()

# %%
df['strike_rate'] = (df_new['runs_scored'].sum()/df_new['balls_faced'].sum())*100
correlation_matrix = df_new[['balls_faced','runs_scored','strike_rate']].corr()
#create the heatmap
plt.figure(figsize=(8,6))
sns.heatmap(data=correlation_matrix,annot=True,cmap='viridis',square=True,fmt=".2f");

# %%
# Calculate strike-rate per oppostion and show as a heat map
# Grouping by 'oppostion'
grouped_by_opposition = df_filtered.groupby('opposition')

# %%
# Aggregating 'balls_faced' and 'runs_scored' using sum
agg_sum = grouped_by_opposition.agg({'balls_faced': 'sum', 'runs_scored': 'sum'})

# %%
# Assigning the result to df_strike_rate
df_strike_rate = agg_sum

# %%
# Calculate the strike_rate
df_strike_rate['strike_rate'] = (df_strike_rate['runs_scored'] / df_strike_rate['balls_faced']) * 100

# %%
# Resetting index to make 'opposition' a  regular column
# df_strike_rate.reset_index(inplace=True)
# NO - We do want opposition as index for heatmap to be possible
# Display the resulting DataFrame
print(df_strike_rate)

# %%
#Bad graph - only retain strike rate column
df_strike_rate = df_strike_rate[['strike_rate']]
sns.heatmap(df_strike_rate,lw=0.5,annot=True,fmt='.0f',cmap='viridis')
plt.show()

# %%
#Good graph 
df_strike_rate = df_strike_rate[['strike_rate']]
sns.heatmap(df_strike_rate,lw=0.5,annot=True,fmt='.0f',cmap='viridis')
plt.show()

# %%
#Resetting index of make 'opposition' a regular column
df_strike_rate.reset_index(inplace=True)
plt.figure(figsize=(10,8))
plt.bar(df_strike_rate['opposition'],df_strike_rate['strike_rate'],color='skyblue')

aggregate_strike_rate= df_strike_rate['strike_rate'].mean()
plt.axhline(y=aggregate_strike_rate,color='red',linestyle='--',label='Career Strike Rate')

#Set labels and titles
plt.xlabel('Country')
plt.ylabel('Strike Rate')
plt.title('Strike Rate by Country')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
grouped_by_opposition = df_filtered.groupby('opposition')
agg_sum = grouped_by_opposition.agg({ 'runs_scored': 'sum','fours':'sum','sixes':'sum'})
df_runs_boundry=agg_sum
# Calculate the strike_rate
df_runs_boundry['runs_in_boundaries'] = (df_runs_boundry['fours']*4 + df_runs_boundry['sixes']*6)
print(df_runs_boundry)
grouped_by_opposition=df_runs_boundry.groupby('opposition')
df_boundry_grp = grouped_by_opposition.sum().reset_index()

# %%
# Stacked bar plot
plt.figure(figsize=(10, 6))
plt.bar(df_boundry_grp['opposition'], df_boundry_grp['runs_scored'], label='Runs Scored')
plt.bar(df_boundry_grp['opposition'], df_boundry_grp['runs_in_boundaries'], bottom=df_boundry_grp['runs_scored'], label='Runs in Boundaries')

plt.xlabel('Opposition')
plt.ylabel('Runs')
plt.title('Runs Scored and Runs in Boundaries by Opposition')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Same thing  - side by side bar plot
plt.figure(figsize=(10,6))
bar_width = 0.35
index = np.arange(len(df_boundry_grp['opposition']))
plt.bar(index,df_boundry_grp['runs_scored'],width=bar_width,label='Runs Scored')
plt.bar(index+bar_width,df_boundry_grp['runs_in_boundaries'],width=bar_width,label='Runs in Boundaries')
plt.xlabel('Opposition')
plt.ylabel('Runs')
plt.title('Runs Scored and Runs in Boundaries by Opposition')
plt.legend()
plt.xticks(index+bar_width/2,df_boundry_grp['opposition'],rotation=45)
plt.tight_layout()
plt.show()

# %%
df_pair_plot = df_filtered[['opposition','runs_scored','balls_faced','fours','sixes']]
print(df_pair_plot)

# %%
#Pair plot
sns.pairplot(df_pair_plot,hue='opposition',palette='viridis')
plt.show()

# %% [markdown]
# ## 16 April
