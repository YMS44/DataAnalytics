# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:/DataAnalytics/alphabet_stock_data.csv")
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# ...

# %%
'''1. Write a Pandas program to create a line plot of the historical stock prices of
Alphabet Inc. between two specific dates.'''


df['Date'] = pd.to_datetime(df['Date'])
df['Date']

start_date = '2020-04-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

plt.plot(df_filtered['Date'], df_filtered['Close'])

plt.title('Historical Stock Prices of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
'''2. Write a Pandas program to create a line plot of the opening, closing stock
prices of Alphabet Inc. between two specific dates.'''

df['Date'] = pd.to_datetime(df['Date'])
df['Date']

start_date = '2020-04-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]


plt.plot(df_filtered['Date'], df_filtered['Close'], label='Closing')
plt.plot(df_filtered['Date'], df_filtered['Open'], label='Opening')

plt.title('Historical Stock Prices of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
'''3. Write a Pandas program to create a bar plot of the trading volume of Alphabet
Inc. stock between two specific dates.'''

df['Date'] = pd.to_datetime(df['Date'])
df['Date']

start_date = '2020-04-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

plt.bar(df_filtered['Date'], df_filtered['Volume'])

plt.title('Trading Volume of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
'''4. Write a Pandas program to create a bar plot of opening, closing stock prices of
Alphabet Inc. between two specific dates.'''

df['Date'] = pd.to_datetime(df['Date'])
df['Date']

start_date = '2020-04-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]


plt.bar(df_filtered['Date'], df_filtered['Close'], label='Closing')
plt.bar(df_filtered['Date'], df_filtered['Open'], label='Opening')

plt.title('Historical Stock Prices of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
'''5. Write a Pandas program to create a stacked bar plot of opening, closing stock
prices of Alphabet Inc. between two specific dates.'''

df['Date'] = pd.to_datetime(df['Date'])
df['Date']

start_date = '2020-09-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_stacked = df_filtered[['Date','Open','Close']]

df_stacked.set_index('Date', inplace=True)

df_stacked.plot.bar(stacked=True)

#plt.bar(df_filtered['Date'], df_filtered['Close'], label='Closing')
#plt.bar(df_filtered['Date'], df_filtered['Open'], label='Opening')

plt.title('Historical Stock Prices of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
'''6. Write a Pandas program to create a horizontal stacked bar plot of opening,
closing stock prices of Alphabet Inc. between two specific dates.'''

df['Date'] = pd.to_datetime(df['Date'])
df['Date']

start_date = '2020-09-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_stacked = df_filtered[['Date','Open','Close']]

df_stacked.set_index('Date', inplace=True)

df_stacked.plot.barh(stacked=True)

plt.title('Historical Stock Prices of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

# %%
'''7. Write a Pandas program to create a histograms plot of opening, closing, high,
low stock prices of Alphabet Inc. between two specific dates.'''

df['Date'] = pd.to_datetime(df['Date'])

start_date = '2020-05-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_hist = df_filtered[['Open','Close','High','Low']]

plt.figure(figsize=(25,25))
df_hist.hist(alpha=0.5)
plt.suptitle('Opening/Closing/High/Low stock prices of Alphabet Inc', fontsize=12, color='blue')
plt.show()

# %%
'''8. Write a Pandas program to create a stacked histograms plot of opening,
closing, high, low stock prices of Alphabet Inc. between two specific dates.'''

df['Date'] = pd.to_datetime(df['Date'])


start_date = '2020-09-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_stacked = df_filtered[['Open','Close','High','Low']]

df_stacked.plot.hist(stacked=True, bins=100)

plt.title('Opening/Closing/High/Low stock prices of Alphabet Inc.')
plt.xlabel('Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
'''9. Write a Pandas program to draw a horizontal and cumulative histograms plot
of opening stock prices of Alphabet Inc. between two specific dates.'''

import pandas as pd
import matplotlib.pyplot as plt


df['Date'] = pd.to_datetime(df['Date'])

# Filter the data between the two specific dates
start_date = '2020-04-01'
end_date = '2020-04-30'                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)

df1 = df.loc[new_df]
df2 = df1[['Open']]

plt.figure(figsize=(15,15))
df2.plot.hist(orientation='horizontal',cumulative=True)
plt.suptitle('Opening stock prices of Alphabet Inc.,\n From 01-04-2020 to 30-04-2020', fontsize=12, color='black')
plt.show()

# %%
'''10. Write a Pandas program to create a stacked histograms plot of opening,
closing, high, low stock prices of Alphabet Inc. between two specific dates with
more bins.'''
df['Date'] = pd.to_datetime(df['Date'])


start_date = '2020-09-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_stacked = df_filtered[['Open','Close','High','Low']]

df_stacked.plot.hist(stacked=True, bins=125)

plt.title('Opening/Closing/High/Low stock prices of Alphabet Inc.')
plt.xlabel('Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
'''11. Write a Pandas program to create a stacked histograms plot with more bins
of opening, closing, high, low stock prices of Alphabet Inc. between two specific
dates.'''

df['Date'] = pd.to_datetime(df['Date'])


start_date = '2020-09-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_stacked = df_filtered[['Open','Close','High','Low']]

df_stacked.plot.hist(stacked=True, bins=125)

plt.title('Opening/Closing/High/Low stock prices of Alphabet Inc.')
plt.xlabel('Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
'''12. Write a Pandas program to create a plot of stock price and trading volume of
Alphabet Inc. between two specific dates.
'''

df['Date'] = pd.to_datetime(df['Date'])


start_date = '2020-09-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_stacked = df_filtered[['High','Volume']]

df_stacked.plot.hist(stacked=True, bins=10)

plt.title('Opening/Closing/High/Low stock prices of Alphabet Inc.')
plt.xlabel('Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
'''13. Write a Pandas program to create a plot of Open, High, Low, Close, Adjusted
Closing prices and Volume of Alphabet Inc. between two specific dates.'''

df['Date'] = pd.to_datetime(df['Date'])


start_date = '2020-09-01'
end_date = '2020-09-30'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

df_stacked = df_filtered[['Open','Close','High','Low','Adj Close','Volume']]

df_stacked.plot.hist(stacked=True, bins=10)

plt.title('Opening/Closing/High/Low stock prices of Alphabet Inc.')
plt.xlabel('Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
'''14. Write a Pandas program to create a plot of adjusted closing prices, thirty
days and forty days simple moving average of Alphabet Inc. between two specific
dates.'''

start_date ='2020-04-01'
end_date ='2020-04-30' # Adjust this as needed

filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

filtered_df['30-day SMA'] = filtered_df['Adj Close'].rolling(window=30).mean()
filtered_df['40-day SMA'] = filtered_df['Adj Close'].rolling(window=40).mean()


plt.figure(figsize=(10, 6))
plt.plot(filtered_df['Date'], filtered_df['Adj Close'], label='Adjusted Closing Price')
plt.plot(filtered_df['Date'], filtered_df['30-day SMA'], label='30-day SMA')
plt.plot(filtered_df['Date'], filtered_df['40-day SMA'], label='40-day SMA')

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Closing Prices and Moving Averages for Alphabet Inc.')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\AppData\Local\Temp\ipykernel_17344\833665609.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['30-day SMA'] = filtered_df['Adj Close'].rolling(window=30).mean()
# C:\Users\Administrator.DAI-PC2\AppData\Local\Temp\ipykernel_17344\833665609.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['40-day SMA'] = filtered_df['Adj Close'].rolling(window=40).mean()

# %%
'''15. Write a Pandas program to create a plot of adjusted closing prices, 30 days
simple moving average and exponential moving average of Alphabet Inc.
between two specific dates.'''

start_date ='2020-04-01'
end_date ='2020-04-30'
filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

filtered_df['30-day SMA'] = filtered_df['Adj Close'].rolling(window=30).mean()


filtered_df['EMA'] = filtered_df['Adj Close'].ewm(span=30, adjust=False).mean()


plt.figure(figsize=(10, 6))
plt.plot(filtered_df['Date'], filtered_df['Adj Close'], label='Adjusted Closing Price')
plt.plot(filtered_df['Date'], filtered_df['30-day SMA'], label='30-day SMA')
plt.plot(filtered_df['Date'], filtered_df['EMA'], label='Exponential Moving Average (EMA)')

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Closing Prices, 30-day SMA, and EMA for Alphabet Inc.')
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\AppData\Local\Temp\ipykernel_17344\1759543149.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['30-day SMA'] = filtered_df['Adj Close'].rolling(window=30).mean()
# C:\Users\Administrator.DAI-PC2\AppData\Local\Temp\ipykernel_17344\1759543149.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['EMA'] = filtered_df['Adj Close'].ewm(span=30, adjust=False).mean()

# %%
'''16. Write a Pandas program to create a scatter plot of the trading volume/stock
prices of Alphabet Inc. stock between two specific dates.'''
start_date ='2020-04-01'
end_date ='2020-04-30'
filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

filtered_df['Date'] = pd.to_datetime(filtered_df['Date'])

plt.figure(figsize=(15, 10))
plt.scatter(filtered_df['Close'], filtered_df['Volume'], s=100)
plt.grid(True)
plt.title('Trading Volume/Price of Alphabet Inc. stock\n01-04-2020 to 30-09-2020', fontsize=14, color='black')
plt.xlabel("Stock Price", fontsize=12, color='black')
plt.ylabel("Trading Volume", fontsize=12, color='black')
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\AppData\Local\Temp\ipykernel_17344\515106577.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Date'] = pd.to_datetime(filtered_df['Date'])

# %%
'''17. Write a Pandas program to create a plot to visualize daily percentage returns
of Alphabet Inc. stock price between two specific dates.'''
start_date ='2020-04-01'
end_date ='2020-04-30'
filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

filtered_df['Daily Returns'] = filtered_df['Adj Close'].pct_change() * 100

plt.figure(figsize=(10, 6))
plt.plot(filtered_df['Date'], filtered_df['Daily Returns'], color='b', marker='o', linestyle='-')
plt.xlabel('Date')
plt.ylabel('Daily Percentage Returns')
plt.title('Daily Percentage Returns of Alphabet Inc. Stock Price\n01-04-2020 to 30-09-2020')
plt.grid(True)
plt.xticks(rotation=80)
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\AppData\Local\Temp\ipykernel_17344\3497526806.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Daily Returns'] = filtered_df['Adj Close'].pct_change() * 100

# %%
'''18. Write a Pandas program to plot the volatility over a period of time of Alphabet
Inc. stock price between two specific dates.'''
# Out:
# C:\Users\Administrator.DAI-PC2\AppData\Local\Temp\ipykernel_17344\1304211041.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Daily Returns'] = filtered_df['Adj Close'].pct_change() * 100

# %%
'''19. Write a Pandas program to create a histogram to visualize daily return
distribution of Alphabet Inc. stock price between two specific dates.'''

start_date ='2020-04-01'
end_date ='2020-04-30'
filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

filtered_df['Daily Returns'] = filtered_df['Adj Close'].pct_change() * 100

filtered_df.plot.hist()
#plt.hist(filtered_df['Date'], filtered_df['Daily Returns'], color='b', marker='o', linestyle='-')
plt.xlabel('Date')
plt.ylabel('Daily Percentage Returns')
plt.title('Daily Percentage Returns of Alphabet Inc. Stock Price\n01-04-2020 to 30-09-2020')
plt.grid(True)
plt.xticks(rotation=80)
plt.show()
# Out:
# C:\Users\Administrator.DAI-PC2\AppData\Local\Temp\ipykernel_17344\4153392095.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Daily Returns'] = filtered_df['Adj Close'].pct_change() * 100
